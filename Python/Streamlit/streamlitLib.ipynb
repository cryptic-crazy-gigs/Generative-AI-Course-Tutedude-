# %% [markdown]
# #  Streamlit

# %% [markdown]
# ### Streamlit is an openource python library used to build Beautiful, interactive web applications for data science and machine learning with minimal effort

# %% [markdown]
# ## why to use streamlit
#
# #### easy to use
# #### fast development
# #### interactive UI elements ---> buttons, sliders, Text inputs, Charts, etc
# #### grt for data science ----> supports pandas, Matplotlib, Plotly and other libraries
# #### Deployment is easy
