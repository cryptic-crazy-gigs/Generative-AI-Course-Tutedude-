# %% [markdown]
# # Python Introduction

# %%
1+2+3+4+5
# Out:
# 15

# %%
1+2+3+4+5+\
    6+7  # \ for continuation
# Out:
# 28

# %% [markdown]
# line continuation : \ for continuation of statements on the next line

# %% [markdown]
# ## multiple statements in single line in python

# %%
a=10 ; b=5 ; c=3
