# %% [markdown]
# # Modules and Packges

# %%
def addition(num1, num2):
    return num1+num2

# %%
addition(4,5)
# Out:
# 9

# %% [markdown]
# ## I want to use this logic of the function in this file into the other files

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
round(math.sqrt(12),3)
# Out:
# 3.464

# %%
## how complex the logic of square root function is going to be

# %% [markdown]
# ## Module
#
# #### a module in python is a file that contains python code(functions, classes, variables) that can be imported and used in other programs

# %% [markdown]
# ### Numpy ----> Numpy module is going to help us out with applying scientific calculations on the array and we can store our data by consuming less space and we can apply the operations with our array a bit more faster as compared to those of the list
#
# ### ---> we can do it in Numpy just because Numpy is having the collection of functions and attributes which can help us to work efficiently with the array

# %% [markdown]
# ## Pandas
#
# #### Pandas also helping out in making datasets from webscraping websites
# #### Pandas we can use when we are going to work with the dataset for cleaning, preprocessing, EDA, analysis with plotting as well

# %% [markdown]
# # Math

# %% [markdown]
# #### math module consists of all the functions and attributes which will help us out in mathemmatical calculations

# %%
import math

math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt
sqrt(16)
# Out:
# 4.0

# %%
from math import *  # allows us to bring all the functions, attributes from the module math
print(pi)  # pi --> an attribute
# Out:
# 3.141592653589793

# %%
'''
A Module :

1. A module helps in code organisation
2. It promotes reusability
3. It keeps the code clean and manageable

'''
# Out:
# '\nA Module :\n\n1. A module helps in code organisation\n2. It promotes reusability\n3. It keeps the code clean and manageable\n\n'

# %%
print(cos(90))
# Out:
# -0.4480736161291701

# %%
print(factorial(5))
# Out:
# 120

# %%
import numpy

# %%
import pandas

# %%
import matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import matplotlib
#       2
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# #### All modules are not preinstalled in the environment. Some modules like math module are preinsstalled. Others like numpy, pandas, matplotlib, scikit learn, nltk, pytorch, tensorflow are not preinstalled. They have to be installed explicitly in the environment

# %%
import numpy

# %%
list_items = [1 ,2 ,3 ,4 ,5]
numpy_array = numpy.array(list_items)
print(numpy_array)
print(type(numpy_array))

# numpy_array is an object of the numpy class
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
! pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------- ----------------------- 3.9/9.3 MB 19.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.6/9.3 MB 16.1 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.3 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 12.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 18.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    -------------------- ------------------- 3.7/7.1 MB 18.1 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.1 MB 15.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 13.2 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
# ...

# %% [markdown]
# ### I am trying to create my own library or module and in this library i want the functions and the attributes to be created on my own

# %%
##### __init__.py is a file that has to be there inside the package folder and this __init__.py file helps us out in defining 
# our packages and initialising their namespaces

##### __init__.py file can remain empty and its completely fine but this file has to be there when we will be creating our 
# new packages into the package folder

# %%
from Package_Folder.mathematics import addition

# %%
addition(5, 10)
# Out:
# 15

# %%
subtraction(10, 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 subtraction(10, 5)
#
# NameError: name 'subtraction' is not defined

# %% [markdown]
# so, package_folder is a package
# mathematics is a module
# addition is a function inside the module

# %%
from Package_Folder.mathematics import *

# %%
division(4,0)
# Out:
# 'Invalid Input'

# %%
division(8,2)
# Out:
# 4.0

# %%
cd python file_name.py
# to run/execute the file_name.py in cmd prompt

# %%
from Package_Folder.subPackage.sum import *

Sum(4,5,6)
# Out:
# 15

# %%
Sum(4,5,6)
# Out:
# 15
