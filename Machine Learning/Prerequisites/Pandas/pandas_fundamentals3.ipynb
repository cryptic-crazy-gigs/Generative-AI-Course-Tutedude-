# %% [markdown]
# ## Series with python functionalities
#
# #### len ---> It provies the idea with total number of elements present in the series
# #### type ---> It provides the idea about the data type of the series
# #### dir ----> It provides with the idea about all of the methods and attributes associated with the Series
# #### sorted --> sort the values in ascending manner
# #### max --> calculates max value in the Series
# #### min --> calculates min value in the Series

# %%
import numpy as np
import pandas as pd

# %%
youtube = pd.read_csv('youtube_2025_dataset_202504061614.csv')

# %%
dataframe = youtube.set_index('Youtuber Name')['Total Videos']

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
len(dataframe)
# Out:
# 5000

# %%
type(dataframe)
# Out:
# pandas.Series

# %%
dir(dataframe)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
# ...

# %%
avg = youtube['Avg Video Length (min)']

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
sorted(avg)
# Out:
# [19.1,
#  19.3,
#  19.9,
#  20.6,
#  20.7,
#  20.9,
#  20.9,
#  20.9,
#  21.0,
#  21.1,
#  21.2,
#  21.3,
#  21.3,
#  21.3,
#  21.3,
#  21.3,
#  21.4,
#  21.4,
#  21.4,
#  21.4,
#  21.4,
#  21.4,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.8,
#  21.8,
#  21.8,
#  21.8,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
# ...

# %%
sorted(dataframe)
# Out:
# [50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  52,
#  52,
#  52,
#  52,
#  52,
#  52,
#  52,
#  52,
#  52,
#  52,
#  52,
#  52,
#  52,
#  52,
#  53,
#  53,
#  53,
#  53,
#  53,
#  53,
#  53,
#  53,
#  53,
#  53,
#  53,
#  53,
#  53,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  55,
#  55,
#  55,
#  55,
#  55,
#  55,
#  55,
#  55,
#  55,
#  55,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  57,
#  57,
#  57,
#  57,
#  57,
#  57,
#  57,
#  58,
#  58,
#  58,
#  58,
#  58,
#  58,
#  58,
#  58,
#  58,
#  58,
#  59,
#  59,
#  59,
#  59,
#  59,
#  59,
#  59,
#  59,
#  59,
#  59,
#  59,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  61,
#  61,
#  61,
#  61,
#  61,
#  61,
#  61,
#  61,
#  61,
#  61,
#  61,
#  62,
# ...

# %%
## Package Function  ---> object.function()
## Built in Functionality  ---> function(object)

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
max(avg)
# Out:
# 28.9

# %%
type(sorted(avg))
# Out:
# list

# %%
type(avg.sort_values())
# Out:
# pandas.Series

# %%
min(avg)
# Out:
# 19.1

# %% [markdown]
# ## Type conversion in Series (just like python)
#
# #### ---> I can convert the data type of the given series into another data type
# #### Series ---> List ---> list(Series)
# #### Series ---> Dictionary ---> dict(Series)

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
list_avg = list(avg)

# %%
list_avg
# Out:
# [24.8,
#  22.9,
#  24.0,
#  24.6,
#  24.6,
#  24.2,
#  23.2,
#  25.6,
#  23.1,
#  24.2,
#  22.9,
#  25.4,
#  26.9,
#  23.4,
#  24.1,
#  24.9,
#  24.7,
#  24.8,
#  23.6,
#  24.1,
#  24.8,
#  24.2,
#  23.2,
#  23.4,
#  24.9,
#  24.2,
#  23.3,
#  23.6,
#  25.5,
#  25.2,
#  24.6,
#  24.9,
#  23.7,
#  23.2,
#  24.1,
#  24.0,
#  24.3,
#  23.8,
#  23.6,
#  24.9,
#  24.0,
#  23.4,
#  23.3,
#  23.9,
#  23.8,
#  24.5,
#  22.9,
#  23.1,
#  23.4,
#  23.9,
#  25.6,
#  23.3,
#  24.6,
#  23.9,
#  23.1,
#  24.9,
#  23.0,
#  24.1,
#  24.0,
#  23.4,
#  24.9,
#  25.9,
#  24.7,
#  23.5,
#  24.0,
#  25.8,
#  23.7,
#  23.9,
#  23.8,
#  24.0,
#  24.0,
#  24.1,
#  25.1,
#  24.3,
#  23.9,
#  23.5,
#  24.4,
#  22.9,
#  23.1,
#  25.1,
#  24.8,
#  23.7,
#  24.1,
#  24.4,
#  23.9,
#  22.1,
#  23.7,
#  24.5,
#  24.2,
#  23.8,
#  24.2,
#  22.8,
#  24.9,
#  24.4,
#  27.0,
#  23.2,
#  24.5,
#  26.1,
#  23.4,
#  23.4,
#  24.1,
#  22.3,
#  24.1,
#  24.3,
#  24.1,
#  24.8,
#  23.8,
#  23.7,
#  24.2,
#  24.4,
#  23.7,
# ...

# %%
type(list_avg)
# Out:
# list

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
dict_dataframe = dict(dataframe)

# %%
type(dict_dataframe)
# Out:
# dict

# %% [markdown]
# ## Membership Operators
# #### Membership Operators --> in  --> It checks whether if a value is in the Series or not
# #### it checks for the element in the index or label of the series
# #### we can go with df.values to check that whether if a member is of a Series or not

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
'Amit Singh' in dataframe
# Out:
# False

# %%
'Lisa Burke' in dataframe
# Out:
# True

# %%
90 in dataframe.values
# Out:
# True

# %%
1500 in dataframe.values
# Out:
# False

# %%
150 in dataframe.values
# Out:
# True

# %%
## Looping in Series --> for loop for iterating over the items of 
# the Series and for the index iterating we can go with series_name.index

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
for i in avg :
    print(i)
# Out:
# 24.8
# 22.9
# 24.0
# 24.6
# 24.6
# 24.2
# 23.2
# 25.6
# 23.1
# 24.2
# 22.9
# 25.4
# 26.9
# 23.4
# 24.1
# 24.9
# 24.7
# 24.8
# 23.6
# 24.1
# 24.8
# 24.2
# 23.2
# 23.4
# 24.9
# 24.2
# 23.3
# 23.6
# 25.5
# 25.2
# 24.6
# 24.9
# 23.7
# 23.2
# 24.1
# 24.0
# 24.3
# 23.8
# 23.6
# 24.9
# 24.0
# 23.4
# 23.3
# 23.9
# 23.8
# 24.5
# 22.9
# 23.1
# 23.4
# 23.9
# 25.6
# 23.3
# 24.6
# 23.9
# 23.1
# 24.9
# 23.0
# 24.1
# 24.0
# 23.4
# 24.9
# 25.9
# 24.7
# 23.5
# 24.0
# 25.8
# 23.7
# 23.9
# 23.8
# 24.0
# 24.0
# 24.1
# 25.1
# 24.3
# 23.9
# 23.5
# 24.4
# 22.9
# 23.1
# 25.1
# 24.8
# 23.7
# 24.1
# 24.4
# 23.9
# 22.1
# 23.7
# 24.5
# 24.2
# 23.8
# 24.2
# 22.8
# 24.9
# 24.4
# 27.0
# 23.2
# 24.5
# 26.1
# 23.4
# 23.4
# 24.1
# 22.3
# 24.1
# 24.3
# 24.1
# 24.8
# 23.8
# 23.7
# 24.2
# 24.4
# 23.7
# 24.2
# 23.1
# 23.4
# 23.9
# 23.9
# 23.6
# 23.4
# 25.6
# 23.3
# 24.1
# 23.4
# 24.7
# 24.8
# 23.9
# 24.4
# 25.1
# 22.9
# 24.6
# 24.4
# 25.0
# 23.7
# 23.6
# 24.7
# 26.0
# 22.8
# 23.6
# 22.8
# 23.2
# 22.9
# 22.4
# 24.3
# ...

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
for i in dataframe.index:
    print(i)
# Out:
# Eric Patel
# Cynthia Harrington
# Amanda Walker
# Jessica Nelson MD
# Matthew Sherman
# Anna Berry
# Richard Arnold
# Stephanie Potter
# Teresa Aguirre
# Anne Adkins
# David Clark
# Kathleen Weeks
# Melissa Kennedy
# Kimberly Brown
# Jennifer Martinez
# Elizabeth Wright
# Elijah Ruiz
# Thomas Roberts
# Julian Gutierrez
# Sheila Rivera
# Crystal Vargas
# Kevin Marquez
# Gregory Norman
# Jason Hall
# Jacob Patterson
# Daniel Costa
# Vincent Graves
# Anthony Huynh
# Michelle Rogers
# Alison Scott
# Sherry Reed
# Mr. James Montgomery
# Leah Moss
# Shelby Pace
# Tracie Hogan
# Mrs. Katelyn Soto
# Monica Henry
# Kevin Martinez MD
# Kathryn Harris
# Allison Phillips
# Maxwell Anderson
# Terry Meyer
# Wanda Hernandez
# Brenda Boyd
# Anna Frank
# Heather Jefferson
# Michelle Martinez
# Sara Mack
# Christopher Taylor
# Larry Zimmerman
# David Craig
# Antonio Reilly
# Oscar Gallegos
# William White
# Brittany Dickerson
# Jennifer Kane
# Shannon Rodriguez
# Sarah Little
# Timothy Page
# ...

# %%
## Arithmetic Operators in Series

# %%
df = youtube['Channel Name']

# %%
df
# Out:
# 0                   Smith-Ross Labs
# 1                  Sandoval PLC Hub
# 2       Jones, Moore and Ho Network
# 3              Mitchell-Hooper Labs
# 4                Wilson LLC Studios
#                    ...
# 4995          Flores-Daniel Studios
# 4996       Spencer and Sons Studios
# 4997         Obrien-Roberts Studios
# 4998                   King Ltd Hub
# 4999              Henry Ltd Studios
# Name: Channel Name, Length: 5000, dtype: str

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
added_data = dataframe + 100

# %%
added_data
# Out:
# Youtuber Name
# Eric Patel            168
# Cynthia Harrington    228
# Amanda Walker         382
# Jessica Nelson MD     402
# Matthew Sherman       229
#                      ...
# Jasmine Smith         206
# John Rasmussen        230
# Lisa Burke            279
# Steve Diaz            282
# Austin Tate           192
# Name: Total Videos, Length: 5000, dtype: int64

# %%
diff_data = added_data - 50

# %%
diff_data
# Out:
# Youtuber Name
# Eric Patel            118
# Cynthia Harrington    178
# Amanda Walker         332
# Jessica Nelson MD     352
# Matthew Sherman       179
#                      ...
# Jasmine Smith         156
# John Rasmussen        180
# Lisa Burke            229
# Steve Diaz            232
# Austin Tate           142
# Name: Total Videos, Length: 5000, dtype: int64

# %%
multiplied_data = diff_data*2

# %%
multiplied_data
# Out:
# Youtuber Name
# Eric Patel            236
# Cynthia Harrington    356
# Amanda Walker         664
# Jessica Nelson MD     704
# Matthew Sherman       358
#                      ...
# Jasmine Smith         312
# John Rasmussen        360
# Lisa Burke            458
# Steve Diaz            464
# Austin Tate           284
# Name: Total Videos, Length: 5000, dtype: int64

# %% [markdown]
# ## Relational Operators in Series

# %%
400 > multiplied_data
# Out:
# Youtuber Name
# Eric Patel             True
# Cynthia Harrington     True
# Amanda Walker         False
# Jessica Nelson MD     False
# Matthew Sherman        True
#                       ...
# Jasmine Smith          True
# John Rasmussen         True
# Lisa Burke            False
# Steve Diaz            False
# Austin Tate            True
# Name: Total Videos, Length: 5000, dtype: bool

# %% [markdown]
# ## Boolean Indexing in Series
#
# #### In order to perform the Important analysis on the column values, where in a specific index value if it is meeting a condition that we get True over their else we get False when the codition is not meeting for that specific index.
#
# ##### Boolean index ---> True ---> Condition is True
# ##### Boolean index ---> False --> Condition is not True

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
### which youtubers are having average length greater than 24 minutes

# %%
avg[avg>24]
# Out:
# 0       24.8
# 3       24.6
# 4       24.6
# 5       24.2
# 7       25.6
#         ...
# 4994    24.8
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 2381, dtype: float64

# %%
avg[avg>24].size
# Out:
# 2381

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
dataframe>120
# Out:
# Youtuber Name
# Eric Patel            False
# Cynthia Harrington     True
# Amanda Walker          True
# Jessica Nelson MD      True
# Matthew Sherman        True
#                       ...
# Jasmine Smith         False
# John Rasmussen         True
# Lisa Burke             True
# Steve Diaz             True
# Austin Tate           False
# Name: Total Videos, Length: 5000, dtype: bool

# %%
dataframe[dataframe > 120]
# Out:
# Youtuber Name
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
# Richard Arnold        494
#                      ...
# Howard Phelps         126
# Sharon Graham         231
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Name: Total Videos, Length: 4175, dtype: int64

# %%
dataframe[dataframe>150].size
# Out:
# 3839

# %% [markdown]
# ### Plotting Graphs in Pandas
#
# #### for plotting graphs in Pandas, we require plot() --> df.plot()
#
# #### kind parameter --> It decides what kind of graph you want to plot

# %%
df
# Out:
# 0                   Smith-Ross Labs
# 1                  Sandoval PLC Hub
# 2       Jones, Moore and Ho Network
# 3              Mitchell-Hooper Labs
# 4                Wilson LLC Studios
#                    ...
# 4995          Flores-Daniel Studios
# 4996       Spencer and Sons Studios
# 4997         Obrien-Roberts Studios
# 4998                   King Ltd Hub
# 4999              Henry Ltd Studios
# Name: Channel Name, Length: 5000, dtype: str

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg.plot()
# Out:
# <Axes: >

# %%
dataframe.sort_values(ascending= False).head(15)
# Out:
# Youtuber Name
# Amy Russo             500
# Eric Riley            500
# David Santiago        500
# Jeremiah Freeman      500
# Dominique Martin      500
# Paul Silva            500
# Miguel Ross           500
# William Jones         500
# Julian Gutierrez      500
# Philip Adkins         500
# Brian Thompson        499
# Willie Stein          499
# James Vaughn          499
# Dr. Eric Smith PhD    499
# Michael Grant         499
# Name: Total Videos, dtype: int64

# %%
dataframe.sort_values(ascending= False).head(15).plot()
## by defaut it makes the dot chart
# Out:
# <Axes: xlabel='Youtuber Name'>

# %%
dataframe.sort_values(ascending= False).head(15).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Youtuber Name'>

# %%
dataframe.sort_values(ascending=False).sample(15)
# Out:
# Youtuber Name
# Steven Tran           338
# Jesse Gutierrez       214
# Richard Fisher        489
# Christopher Thomas    435
# Bruce Howard          436
# Willie Wilkerson      105
# Seth Barnes           140
# Rachel Tate           179
# Andrea Cooper         289
# Linda Gonzalez        123
# Alice Ortiz           116
# Glen Walker           108
# Natalie Pierce        369
# Kim Martinez          405
# Carrie Warren          75
# Name: Total Videos, dtype: int64

# %%
dataframe.sort_values(ascending=False).sample(15).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Youtuber Name'>

# %%
dataframe.sort_values(ascending=False).sample(15).plot(kind ='pie')
# Out:
# <Axes: >
