# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Visualization ---> We can extract Information and Patterns by creating Visuals and Graphs and we can analyze some important insights.
#
# ### 5 visuals ---->  1. 2-D plot or Line Plot
# ### 2. Scatter Plot
# ### 3. Bar chart
# ### 4. Histogram
# ### 5. Pie Chart
